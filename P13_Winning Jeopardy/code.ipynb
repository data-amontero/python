# %% [markdown]
# # P13. Winning Jeopardy
#
# Jeopardy is a TV show in the US where participant answer questions to win money. We will be exploring a dataset of jeopardy questions containing 20000 rows and try to figure out some patterns in it. It could help you win in your next Jeopardy contest.

# %%
import pandas as pd

jeopardy = pd.read_csv('jeopardy.csv')
jeopardy.head(6)
print(jeopardy.columns)

#removing white space in front of column values
col_list = []
for col in jeopardy.columns:
    col_list.append(col.strip())
    
jeopardy.columns = col_list
print(jeopardy.columns)
# Out:
# Index(['Show Number', ' Air Date', ' Round', ' Category', ' Value',
#        ' Question', ' Answer'],
#       dtype='object')
# Index(['Show Number', 'Air Date', 'Round', 'Category', 'Value', 'Question',
#        'Answer'],
#       dtype='object')

# %%
#normalizing Question and Answer columns

def clean_qa(string):
    import re
    to_low = string.lower()
    #remove punctuation
    pattern = '[^A-Za-z0-9\s]'
    return re.sub(pattern, "", to_low)

# %%
jeopardy['clean_question'] = jeopardy['Question'].apply(clean_qa)
jeopardy['clean_answer'] = jeopardy['Answer'].apply(clean_qa)

jeopardy.head(6)
# Out:
#    Show Number    Air Date      Round                         Category Value  \
# 0         4680  2004-12-31  Jeopardy!                          HISTORY  $200
# 1         4680  2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2         4680  2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
# 3         4680  2004-12-31  Jeopardy!                 THE COMPANY LINE  $200
# 4         4680  2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES  $200
# 5         4680  2004-12-31  Jeopardy!                   3-LETTER WORDS  $200
#
#                                             Question      Answer  \
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams
# 5  In the title of an Aesop fable, this insect sh...     the ant
#
#                                       clean_question clean_answer
# 0  for the last 8 years of his life galileo was u...   copernicus
# 1  no 2 1912 olympian football star at carlisle i...   jim thorpe
# 2  the city of yuma in this state has a record av...      arizona
# 3  in 1963 live on the art linkletter show this c...    mcdonalds
# 4  signer of the dec of indep framer of the const...   john adams
# 5  in the title of an aesop fable this insect sha...      the ant

# %%
#Normalizing Value and Air Date columns

def normalize_value(string):
    import re
     #remove punctuation
    pattern = '[^A-Za-z0-9\s]'
    try:
        val = int(re.sub(pattern, '', string))
    except:
        val = 0
        
    return val

# %%
jeopardy['clean_value'] = jeopardy['Value'].apply(normalize_value)

# %%
#Normalize Air Date

jeopardy['Air Date'] = pd.to_datetime(jeopardy['Air Date'])
jeopardy['Air Date'].head()
# Out:
# 0   2004-12-31
# 1   2004-12-31
# 2   2004-12-31
# 3   2004-12-31
# 4   2004-12-31
# Name: Air Date, dtype: datetime64[ns]

# %% [markdown]
# ## Analyzing Answers in Questions
#
# We can see how many times wornds in the answer also occur in the question, to see how often the answer is deducible from the question.

# %%
def count_match(row):
    split_answer = row['clean_answer'].split(" ")
    split_question = row['clean_question'].split(" ")
    match_count = 0
    try:
        split_answer.remove('the')
    except: 
        split_answer
    
    if len(split_answer) == 0:
        return 0
        
    for w in split_answer:
        for q in split_question:
            if w==q:
                match_count += 1
    
    return match_count/len(split_answer)

jeopardy["answer_in_question"] = jeopardy.apply(count_match, axis=1)

# %%
jeopardy['answer_in_question'].mean()
# Out:
# 0.07372317056301256

# %% [markdown]
# The answer appears in the questions in about 7% of all the dataset. It doesn't seem to be very meaningful, we will have to explore the dataset more.

# %% [markdown]
# ## Recycled Questions
#
# Let's investigate how often new questions are repeats of older ones.

# %%
question_overlap = []

terms_used = set()

for idx, row in jeopardy.iterrows():
    split_question = row['clean_question'].split(' ')
    split_question = [q for q in split_question if len(q) > 5]
    match_count = 0
    for w in split_question:
        if w in terms_used:
            match_count += 1
    for w in split_question:
        terms_used.add(w)
    if len(split_question) > 0:
        val = match_count/len(split_question)
    else:
        val = 0
    question_overlap.append(val)


jeopardy['question_overlap'] = question_overlap
jeopardy['question_overlap'].mean()
# Out:
# 0.6908737315671962

# %% [markdown]
# There is about 70% of terms that overlap in new questions and terms in old questions.

# %%
terms_used
# Out:
# {'remodeled',
#  'collaboration',
#  'coroners',
#  'beaten',
#  'entire',
#  'transferrin',
#  'trials',
#  'recovery',
#  'verona',
#  'judases',
#  'lubezki',
#  'oliver',
#  'aggies',
#  'spanishnamed',
#  'hrefhttpwwwjarchivecommedia20060307dj07wmv',
#  'bombardment',
#  'differ',
#  'hrefhttpwwwjarchivecommedia20060601j24jpg',
#  'lespanaye',
#  'bulletin',
#  'evergreen',
#  'lifetime',
#  'requests',
#  'shylock',
#  'yahwehs',
#  'shania',
#  'wubbulous',
#  'outgunned',
#  'articles',
#  'internet',
#  'pharaohs',
#  'loyalists',
#  'chorus',
#  'innards',
#  'impersonated',
#  'minimize',
#  'tearyeyed',
#  'starbuck',
#  'cerdic',
#  'dutchman',
#  'amounts',
#  'amalthea',
#  'annual',
#  'illuminate',
#  'controllers',
#  'regulations',
#  'barker',
#  'viruses',
#  'hrefhttpwwwjarchivecommedia20071203j05jpg',
#  'printedout',
#  'gardens',
#  'haphazardly',
#  'ebonys',
#  'tiananmen',
#  'parodied',
#  'hanshin',
#  'sultanate',
#  'abdulaziz',
#  'carolina',
#  'sergey',
#  'appetizer',
#  'poivre',
#  'baseline',
#  'hrefhttpwwwjarchivecommedia20081222j19ajpg',
#  'nicollier',
#  'giants',
#  'arundel',
#  'yesssssssshe',
#  'region',
#  'cigarette',
#  'cohost',
#  'fashioned',
#  'endorse',
#  'commodity',
#  'phascolarctos',
#  'triloba',
#  'sylvester',
#  'unites',
#  'munichs',
#  'nicholsons',
#  'traviata',
#  'robert',
#  'undergarments',
#  'stealth',
#  'lyndon',
#  'ballou',
#  'anaheims',
#  'shaved',
#  'gallery',
#  'identical',
#  'halfsisters',
#  'majorelle',
#  'induce',
#  'steady',
#  'aquaria',
#  'swapped',
#  'adding',
#  'wellington',
#  'horizons',
#  'maneating',
#  'tearing',
#  'european',
#  'emitter',
#  'breathless',
#  'winder',
#  'targetblankmentona',
#  'whymper',
#  'radius',
#  'andrea',
#  'camino',
#  'salerno',
#  'hrefhttpwwwjarchivecommedia20080602dj23jpg',
#  'drugstoregrandma',
#  'thingamajig',
#  'sleeping',
#  'virtue',
#  'borneo',
#  'hrefhttpwwwjarchivecommedia20090508dj26jpg',
#  'voraciously',
#  'collaborated',
#  'spelled',
#  '287212',
#  'spellbound',
#  'saltwater',
#  'alcantara',
#  'picturephone',
#  'twinkle',
#  'goslin',
#  'safekeeping',
#  'bodysuit',
#  'hedgehogs',
#  'strikeout',
#  'darlene',
#  'hrefhttpwwwjarchivecommedia20070219j01mp3this',
#  'sheldon',
#  'tenskwatawa',
#  'bandleader',
#  'orientation',
#  'gestapo',
#  'tswana',
#  'petrarch',
#  'agreed',
#  'pounded',
#  'marshal',
#  'allegro',
#  'exercising',
#  'chibcha',
#  'medalist',
#  'sturgeon',
#  'ellipses',
#  'grounding',
#  'saharan',
#  'written',
#  'josiah',
#  'lipsynched',
#  'conquest',
#  'seagull',
#  'cartoons',
#  'merchants',
#  'overdone',
#  'bullets',
#  'groundhogs',
#  '22yearold',
#  'sections',
#  'longtailed',
#  'mockingly',
#  'muppets',
#  'targetblankhis',
#  'khartoum',
#  'murders',
#  'spartans',
#  'hrefhttpwwwjarchivecommedia20060213j01wmvjon',
#  'shingleback',
#  'commencement',
#  'purchasing',
#  'segment',
#  'oxpecker',
#  'lothian',
#  'hrefhttpwwwjarchivecommedia19981029dj17jpg',
#  'gentlyamong',
#  'junkie',
#  'tightest',
#  'auschwitz',
#  'rocketed',
#  'armistice',
#  'burkina',
#  'deduction',
#  'windpipe',
#  'banana',
#  'giorgione',
#  'gerard',
#  'boasts',
#  'antony',
#  'shariqah',
#  'sulphur',
#  'courses',
#  'gauche',
#  'truncheons',
#  'ultimate',
#  'eugenides',
#  'kassir',
#  'insectarium',
#  '865foothigh',
#  'shakespeare',
#  'centennial',
#  'scourge',
#  'sapiens',
#  'bratislava',
#  'custis',
#  'harmon',
#  'pueblo',
#  'nitrides',
#  'sanddwelling',
#  'studied',
#  'sprinter',
#  'encrypt',
#  'bostonians',
#  'reefer',
#  'disappeared',
#  'lather',
#  'cranial',
#  'initial',
#  'funnie',
#  'beardless',
#  'partons',
#  'tanzanias',
#  'nimble',
#  'matthew',
#  'encounter',
#  'ellery',
#  'signers',
#  'persuaded',
#  'hrefhttpwwwjarchivecommedia20060329dj26ajpg',
#  'flocks',
#  'winery',
#  'pupils',
#  'highest',
#  'toyota',
#  'affect',
#  'oceana',
#  'kangaroos',
#  'sikelel',
#  'rhebok',
#  'immunosuppressant',
#  'inclinations',
#  'belavia',
#  'comrade',
#  'destroyer',
#  'geiger',
#  'destination',
#  'jobless',
#  'constructing',
#  'formeda',
#  'mexicos',
#  'prototype',
#  'diplomat',
#  'semolina',
#  'talent',
#  'weaken',
#  'squaring',
#  'subsidiary',
#  'exposition',
#  '19451951',
#  'olives',
#  'protectorate',
#  'talons',
#  'zealots',
#  'vertex',
#  'haiphong',
#  'tournament',
#  'asteraceae',
#  'targetblankhiram',
#  'surgical',
#  'baptist',
#  'andorra',
#  'discoverers',
#  'romanian',
#  'bertrams',
#  'correspondant',
#  'gramophone',
#  'sonamed',
#  'crouse',
#  'missing',
#  'controller',
#  'hrefhttpwwwjarchivecommedia20070112j30jpg',
#  'torched',
#  'hrefhttpwwwjarchivecommedia20090504dj13ajpg',
#  'pavonine',
#  'creepy',
#  'hrefhttpwwwjarchivecommedia20070305dj23jpg',
#  'adhering',
#  'climax',
#  'peloponnesus',
#  'hrefhttpwwwjarchivecommedia20070530j16jpg',
#  'accepting',
#  'mechanic',
#  'coulombs',
#  'spielberg',
#  'earwig',
#  'anorak',
#  'annette',
#  'ruthies',
#  'pedigreed',
#  'crescent',
#  'mighty',
#  'mechanical',
#  'kirshner',
#  'cabernet',
#  'excited',
#  'approve',
#  'warhola',
#  'included',
#  'poignant',
#  'hooked',
#  'boswell',
#  'ventures',
#  'suggest',
#  'widens',
#  'perfect',
#  'brunettes',
#  'educator',
#  'doorway',
#  'quotations',
#  'belushi',
#  'coming',
#  'targetblanknew',
#  'hrefhttpwwwjarchivecommedia20090211dj13bjpg',
#  'oclock',
#  'somebodys',
#  'torpedoes',
#  'governs',
#  'adjoins',
#  'gilleys',
#  'reuters',
#  'jeopardys',
#  'targetblankpaintingsa',
#  'displayed',
#  'einkorn',
#  'sanctuary',
#  'creepycrawly',
#  'ganganelli',
#  'stlouis',
#  'virtual',
#  'krating',
#  'hrefhttpwwwjarchivecommedia20090508dj28jpg',
#  'atlanta',
#  'prophets',
#  'hrefhttpwwwjarchivecommedia20090525dj29jpg',
#  'atlantas',
#  'messiah',
#  'hrefhttpwwwjarchivecommedia20091014j06jpg',
#  'guildenstern',
#  'adjectives',
#  'reunited',
#  'dorian',
#  'parlaying',
#  'niccolo',
#  'warnerlambert',
#  'generic',
#  'smelter',
#  'avengers',
#  'injuries',
#  'odette',
#  'neckwear',
#  'wonderful',
#  'singles',
#  'bayreuth',
#  'consolidation',
#  'irrigate',
#  'merton',
#  'pahoehoe',
#  'seventeen',
#  'hoodlike',
#  'bradham',
#  'scorched',
#  'operate',
#  'hrefhttpwwwjarchivecommedia20080404j24ajpg',
#  'courage',
#  'burnham',
#  'geekbrief',
#  'jennifer',
#  'postulated',
#  'monitors',
#  'longestserving',
#  'dingdong',
#  'insectivore',
#  'flooded',
#  'imaginary',
#  'astronomers',
#  'abductions',
#  'ibrahim',
#  'citrine',
#  'picker',
#  'bridgestone',
#  'quicker',
#  'surveyed',
#  'equine',
#  'benefits',
#  'untruea',
#  'investigator',
#  'onehanded',
#  'bodily',
#  'cadaver',
#  'willcox',
#  'hrefhttpwwwjarchivecommedia20081222j27jpg',
#  'grantjimmy',
#  'schmitz',
#  'tablet',
#  'suspicion',
#  'shepard',
#  'zwoarer',
#  'expense',
#  'russian',
#  'austria',
#  'handpicked',
#  'targetblankalex',
#  'purposely',
#  'deforested',
#  'supervisor',
#  'galilean',
#  'deerslayer',
#  'timeeight',
#  'aleichems',
#  'mcadams',
#  'effectiviely',
#  'steamboat',
#  'targetblankbricka',
#  'tuesdays',
#  'jukebox',
#  'diaphragm',
#  'slovakia',
#  'ballyoull',
#  'cocommanders',
#  'appointee',
#  'lesney',
#  'sacred',
#  'kualas',
#  'locomotive',
#  'preliminary',
#  'tossed',
#  'navigators',
#  'cutting',
#  'product',
#  'libyan',
#  'acourting',
#  'mphhence',
#  'sweets',
#  'retaining',
#  'carrying',
#  'navigate',
#  'marathoner',
#  'shopped',
#  'incisors',
#  'predominant',
#  'bhardwaj',
#  'blobitecture',
#  'obscenity',
#  'mischievous',
#  'naples',
#  'hrefhttpwwwjarchivecommedia20091229dj04jpg',
#  '17661768',
#  'preside',
#  'tufting',
#  'innsbruck',
#  'elliot',
#  'cervantes',
#  'somersault',
#  'producers',
#  'highheeled',
#  'bedroom',
#  'hrefhttpwwwjarchivecommedia20050303dj10jpg',
#  'ballpoint',
#  'continually',
#  'family',
#  'graciea',
#  'francisco',
#  'secretary',
#  'verrett',
#  'chiron',
#  'benton',
#  'entered',
#  'seurat',
#  'diminuitive',
#  'singapore',
#  'gluttony',
#  'alarmist',
#  'acronymically',
#  'answered',
#  'acquire',
#  'appraisers',
#  'indians',
#  'clutch',
#  'forested',
#  'maatshappij',
#  'samoan',
#  'hrefhttpwwwjarchivecommedia20080509dj28jpg',
#  'schiller',
#  'schlafly',
#  'margaret',
#  'ottoman',
#  'opentop',
#  'nukualofa',
#  'satire',
#  'demonstration',
#  'larousse',
#  'babushka',
#  'competitive',
#  'bermudas',
#  'fairmont',
#  'eurovision',
#  'targetblankjacoba',
#  'costar',
#  'swarthmore',
#  'banquo',
#  'abruptly',
#  'palestine',
#  'mccafe',
#  'simply',
#  'bismarck',
#  'incomes',
#  'schruns',
#  'sequenced',
#  'sustainable',
#  'having',
#  'predecessor',
#  'pavarotti',
#  'fearful',
#  'barons',
#  'surrealists',
#  'auchincloss',
#  'chastain',
#  'criticisms',
#  'marrow',
#  'humbly',
#  'pfefferminz',
#  'canera',
#  'observe',
#  'deserve',
#  'mcentires',
#  'satisfies',
#  'poisoning',
#  'dispirited',
#  'shipleys',
#  'attending',
#  'january',
#  'attachment',
#  'apparently',
#  'newshour',
#  'lingus',
#  'simpler',
#  'mantle',
#  'autograph',
#  'hrefhttpwwwjarchivecommedia20040712dj12jpg',
#  'interface',
#  'convinced',
#  'cadillac',
#  'katzenjammer',
#  '18yearold',
#  'hester',
#  'intended',
#  'douglass',
#  'milagro',
#  'targetblankshipsa',
#  '75885squaremile',
#  'examined',
#  'licking',
#  'muntader',
#  'codder',
#  '186165',
#  'dolorosa',
#  'klinger',
#  'belongings',
#  'minichest',
#  'fibers',
#  'jealousy',
#  'please',
#  'evidently',
#  'quarto',
#  'targetblankdispensersathe',
#  'reichmusikkammer',
#  'present',
#  'blackboard',
#  'minuscule',
#  'namath',
#  'sleeveless',
#  'overblown',
#  '2letter',
#  'blanches',
#  'castor',
#  'masterpieces',
#  'completed',
#  'kicked',
#  'extremes',
#  'leemans',
#  'guessed',
#  'ireland',
#  'attendees',
#  'addressing',
#  'decades',
#  'rebuilt',
#  'jurisdiction',
#  'variation',
#  'parkway',
#  'hoisting',
#  'pivotal',
#  'hrefhttpwwwjarchivecommedia20070112dj27ajpg',
#  'rolling',
#  'emeritus',
#  'blisters',
#  'attributing',
#  'hrefhttpwwwjarchivecommedia20060425dj15ajpg',
#  'gravestone',
#  'clocked',
#  'dreidels',
#  'consultant',
#  'segovia',
#  'pictorial',
#  'zealander',
#  'brilliant',
#  'definition',
#  'obiwan',
#  'seventh',
#  'mondale',
#  'stuffed',
#  'ignition',
#  'slices',
#  'helicopters',
#  'hippolyta',
#  'protestantism',
#  'glorify',
#  'uneventful',
#  'enceladus',
#  'madonnas',
#  'marketed',
#  'shorthand',
#  'glamis',
#  'midocean',
#  'notsomagnificent',
#  'avantgarde',
#  'bluejays',
#  'rigidly',
#  'sunspots',
#  'descartes',
#  'geisel',
#  'rescue',
#  'length',
#  'highestvalued',
#  'crystallize',
#  'doughnut',
#  'cicely',
#  'vacuum',
#  'antarcticas',
#  'reference',
#  'voices',
#  'hrefhttpwwwjarchivecommedia20090929dj17wmvjimmy',
#  'sonography',
#  '2month',
#  'bobbie',
#  'citystates',
#  'furies',
#  'stubble',
#  'offended',
#  'segels',
#  'keyboard',
#  'blacks',
#  'despise',
#  'australianbuilt',
#  'deformed',
#  'taraxacum',
#  'hrefhttpwwwjarchivecommedia20040723j25jpg',
#  'hrefhttpwwwjarchivecommedia20090504dj30wmvthesea',
#  'sarawak',
#  'ticonderoga',
#  'grisly',
#  'strain',
#  'scrapped',
#  'congreve',
#  'nicolo',
#  'shiitakes',
#  'monarchs',
#  '111yearold',
#  'cognitive',
#  'bacata',
#  'inarritu',
#  'surprisingly',
#  'anyadvanced',
#  'hatter',
#  'synthesized',
#  'ydgrun',
#  'hrefhttpwwwjarchivecommedia20060329j25jpg',
#  'peformed',
#  'alexakis',
#  'hrefhttpwwwjarchivecommedia20101104j12wmvoprah',
#  'stegolophodon',
#  'reputedly',
#  'indianola',
#  'jessica',
#  'aphids',
#  'flirted',
#  'tolkien',
#  'fisher',
#  'epistolary',
#  'queens',
#  'oklahoma',
#  'cathedral',
#  'propertius',
#  'heavily',
#  'tweeds',
#  'superficial',
#  'contractions',
#  'picchu',
#  'oneraw',
#  'hellcats',
#  'diesel',
#  'mangler',
#  'expected',
#  'corollas',
#  'alkaloid',
#  'peters',
#  'worshippers',
#  'hrefhttpwwwjarchivecommedia20050531j05jpg',
#  'snitch',
#  'colony',
#  'fontaine',
#  'therapy',
#  'secrets',
#  'carassos',
#  'reeses',
#  'hrefhttpwwwjarchivecommedia20041109dj13jpg',
#  'possessions',
#  'ornamental',
#  'laurents',
#  'susanna',
#  'samesounding',
#  'flintsones',
#  'scholastica',
#  'rathbun',
#  'remington',
#  'kanagawa',
#  'eclipse',
#  'iphicles',
#  'hatches',
#  'gastropods',
#  'assumes',
#  'stylist',
#  'commas',
#  'transparently',
#  'involved',
#  'plummer',
#  'nighttime',
#  'gruner',
#  'goblin',
#  'hrefhttpwwwjarchivecommedia20061012dj28jpg',
#  'schnitzel',
#  'horseback',
#  'burning',
#  'sitting',
#  'carrie',
#  'rbride',
#  'pincers',
#  'eleven',
#  'naegling',
#  'yonkers',
#  'attica',
#  'vampire',
#  'warship',
#  'kinnan',
#  'cavities',
#  'rabblement',
#  'botanists',
#  'weakened',
#  'immense',
#  'endearment',
#  'wilting',
#  'appearedin',
#  'accusing',
#  'hrefhttpwwwjarchivecommedia20050303dj14ajpg',
#  'tennysons',
#  'corbin',
#  'philbins',
#  'kidnapping',
#  'systems',
#  'hatcher',
#  'casting',
#  'hrefhttpwwwjarchivecommedia20060426j25jpg',
#  '413000',
#  'wimpole',
#  'sonoran',
#  'sendak',
#  'hrefhttpwwwjarchivecommedia20050315j02jpg',
#  'unconfined',
#  'television',
#  'original',
#  '450foot',
#  'cookbook',
#  'growth',
#  'sellers',
#  'spoons',
#  'pretty',
#  'carved',
#  'movements',
#  'yellowing',
#  'kicking',
#  'reefdwelling',
#  'hrefhttpwwwjarchivecommedia20050629j08jpg',
#  'crawfords',
#  'nuclear',
#  'alleged',
#  '13letter',
#  'onethird',
#  'hedgehog',
#  'orsino',
#  'curtain',
#  'idahomontana',
#  'militant',
#  'durability',
#  'budweiser',
#  'brought',
#  'hippity',
#  'strikeouts',
#  'smalls',
#  'dentistry',
#  'hamlet',
#  'buster',
#  'asgard',
#  'mongolians',
#  'catalina',
#  'rentier',
#  'bumbling',
#  'borrower',
#  'storing',
#  'orderly',
#  'counterterrorism',
#  'bestof9',
#  'newsman',
#  'becomes',
#  'blackie',
#  'mondales',
#  'shelley',
#  'funicello',
#  'tabernacle',
#  'sweetener',
#  'collections',
#  'unauthorized',
#  'camper',
#  'clergyman',
#  'aimlessly',
#  'cogsworth',
#  'tonsils',
#  'privileges',
#  '19701982',
#  'reilly',
#  'physics',
#  'fiscal',
#  'hrefhttpwwwjarchivecommedia20080408dj19jpg',
#  'behavioral',
#  'draftsmen',
#  'stately',
#  'lemovices',
#  'dempsey',
#  'leverage',
#  'dainty',
#  'marnie',
#  'judith',
#  'picard',
#  'smoking',
#  'heavier',
#  'commemorate',
#  'exceeding',
#  'panels',
#  'nonstop',
#  'recovers',
#  'rotting',
#  'progress',
#  'charcoal',
#  'tsarinas',
#  'plotted',
#  'tilsit',
#  'occasions',
#  'watery',
#  'poirots',
#  'wielded',
#  'hrefhttpwwwjarchivecommedia20080310dj14jpg',
#  'fallin',
#  'sparked',
#  'schweineschnitzel',
#  'mariners',
#  'bostons',
#  'prosecute',
#  'motorwagen',
#  'continues',
#  'binghams',
#  'hrefhttpwwwjarchivecommedia20041020dj22jpg',
#  'interfere',
#  'fahrenheit',
#  'revolves',
#  'krispies',
#  'neonatal',
#  'exwife',
#  'odense',
#  'pamphlet',
#  'behead',
#  'innsmouth',
#  'dusted',
#  'displacement',
#  'behind',
#  'astrological',
#  'dimaggios',
#  'woodsman',
#  'hrefhttpwwwjarchivecommedia20100319dj25jpg',
#  'vehement',
#  'roulette',
#  'richards',
#  'tycoon',
#  'fitzgeralds',
#  'analects',
#  'sympathy',
#  'abstain',
#  'muchsought',
#  'dancer',
#  'contender',
#  'favorites',
#  'skookum',
#  'gervin',
#  'icarus',
#  'baghdad',
#  'hrefhttpwwwjarchivecommedia20111202j11jpg',
#  'defects',
#  'attorneys',
#  'manager',
#  'scoundrels',
#  'satires',
#  'nadezhda',
#  'endeavor',
#  'cobalt',
#  'hippety',
#  'vanilla',
#  'mosioatunya',
#  'gymnastics',
#  'targetblankexhibita',
#  'unspotted',
#  'sennett',
#  'zuiderzee',
#  'berakah',
#  'panamanian',
#  'hrefhttpwwwjarchivecommedia19980320j17mp3herea',
#  'bronislaw',
#  'shawnee',
#  'zoster',
#  'sopranos',
#  'thencolonial',
#  'performers',
#  'discourteously',
#  'salina',
#  'additions',
#  'radarevading',
#  'addicts',
#  'monsters',
#  'simple',
#  'cosmetic',
#  'democratically',
#  'overcrowded',
#  'hrefhttpwwwjarchivecommedia20050307dj26ajpg',
#  'speleology',
#  'pradesh',
#  'fruity',
#  'kunsthistorisches',
#  'latinos',
#  'shamans',
#  'developer',
#  'airlock',
#  'kiddush',
#  'constitute',
#  'typify',
#  'receptions',
#  'nickleby',
#  'costume',
#  'hrefhttpwwwjarchivecommedia20001123dj01wmvihis',
#  'pizzazz',
#  'biscotti',
#  'hrefhttpwwwjarchivecommedia20060426j24jpg',
#  'bodies',
#  'forming',
#  'rumored',
#  'bakersfield',
#  'chlorpromazine',
#  'crystallography',
#  'betwixt',
#  'headweara',
#  'integrity',
#  'matters',
#  'sturgis',
#  'germany',
#  'madeira',
#  'litterers',
#  'basket',
#  'eyebrows',
#  'asking',
#  'hookah',
#  'battered',
#  ...}

# %% [markdown]
# ## Low Value vs High Value Questions

# %%
def low_high(row):
    if row['clean_value'] > 800:
        value = 1
    else:
        value = 0
    return value

jeopardy['high_value'] = jeopardy.apply(low_high, axis=1)
jeopardy['high_value'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: high_value, dtype: int64

# %%
def low_high_count(word):
    low_count = 0 
    high_count = 0
    for idx, row in jeopardy.iterrows():
        split_question = row['clean_question'].split(' ')
        if word in split_question:
            if row['high_value'] == 1:
                high_count += 1
            else:
                low_count += 1 
    return high_count, low_count

# %%
observed_expected = []
terms_used = list(terms_used)
comparison_terms = terms_used[:5]

for t in comparison_terms:
    result = low_high_count(t)
    observed_expected.append(result)

# %%
comparison_terms
observed_expected
# Out:
# [(0, 1), (0, 2), (1, 0), (1, 7), (1, 5)]

# %% [markdown]
# ## Applying the chi-squared test

# %%
high_value_count = jeopardy[jeopardy['high_value']==1].shape[0]
low_value_count = jeopardy[jeopardy['high_value']==0].shape[0]

from scipy.stats import chisquare
import numpy as np
chi_squared = []

for i in observed_expected:
    total = i[0] + i[1]
    total_prop = total/jeopardy.shape[0]
    expected_high_count = total_prop * high_value_count
    expected_low_count = total_prop * low_value_count
    observed = np.array([i[0], i[1]])
    expected = np.array([expected_high_count, expected_low_count])
    chi_square, p_value = chisquare(observed, expected)
    chi_squared.append([chi_square, p_value])
    
chi_squared
# Out:
# [[0.401962846126884, 0.5260772985705469],
#  [0.803925692253768, 0.3699222378079571],
#  [2.487792117195675, 0.11473257634454047],
#  [1.0229964471766237, 0.31180929640924315],
#  [0.42281054506129573, 0.515537958129453]]
