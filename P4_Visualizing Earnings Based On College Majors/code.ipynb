# %% [markdown]
# # P4. Visualizing Earnings Based on College Majors
#
# In this project we will be using pandas plotting functionality. We are going to be working with a dataset on the job outcomes of students who graduated from college between 2010-2012.

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# %%
recent_grads = pd.read_csv('recent-grads.csv')
recent_grads.iloc[0,:]
recent_grads.head()
recent_grads.tail()
recent_grads.describe(include='all')
# Out:
#               Rank   Major_code                                   Major  \
# count   173.000000   173.000000                                     173
# unique         NaN          NaN                                     173
# top            NaN          NaN  PHYSICAL AND HEALTH EDUCATION TEACHING
# freq           NaN          NaN                                       1
# mean     87.000000  3879.815029                                     NaN
# std      50.084928  1687.753140                                     NaN
# min       1.000000  1100.000000                                     NaN
# 25%      44.000000  2403.000000                                     NaN
# 50%      87.000000  3608.000000                                     NaN
# 75%     130.000000  5503.000000                                     NaN
# max     173.000000  6403.000000                                     NaN
#
#                 Total            Men          Women Major_category  \
# ...

# %%
raw_data_count = recent_grads.shape[0]
raw_data_count
# Out:
# 173

# %%
recent_grads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 21 columns):
# Rank                    173 non-null int64
# Major_code              173 non-null int64
# Major                   173 non-null object
# Total                   172 non-null float64
# Men                     172 non-null float64
# Women                   172 non-null float64
# Major_category          173 non-null object
# ShareWomen              172 non-null float64
# Sample_size             173 non-null int64
# Employed                173 non-null int64
# Full_time               173 non-null int64
# Part_time               173 non-null int64
# Full_time_year_round    173 non-null int64
# Unemployed              173 non-null int64
# Unemployment_rate       173 non-null float64
# Median                  173 non-null int64
# P25th                   173 non-null int64
# P75th                   173 non-null int64
# College_jobs            173 non-null int64
# ...

# %% [markdown]
# **Dropping rows with Missing Values**

# %%
recent_grads = recent_grads.dropna(axis=0)
recent_grads.shape[0]
# Out:
# 172

# %%
recent_grads.plot(x='Sample_size', y='Employed', kind='scatter')

# %% [markdown]
# **Generating Scatter Plots**

# %%
recent_grads.plot(x=['Sample_size'], y=['Median'], kind = 'scatter')
recent_grads.plot(x=['Sample_size'], y=['Unemployment_rate'], kind = 'scatter')
recent_grads.plot(x=['Full_time'], y=['Median'], kind = 'scatter')
recent_grads.plot(x=['ShareWomen'], y=['Unemployment_rate'], kind = 'scatter')
recent_grads.plot(x=['Men'], y=['Median'], kind = 'scatter')
recent_grads.plot(x=['Women'], y=['Median'], kind = 'scatter')

# %% [markdown]
# **Generating Histogram Plots**

# %%
recent_grads['Sample_size'].hist(bins=25, range=(0,3000))

# %%
recent_grads['Median'].hist(bins=10, range=(0,100))

# %%
recent_grads['Full_time'].hist(bins=20, range=(0,3000))

# %%
recent_grads['ShareWomen'].hist(bins=10, range=(0,10))

# %%
recent_grads['Unemployment_rate'].hist(bins=10, range=(0,10))

# %%
recent_grads['Men'].hist(bins=25, range=(0,3000))

# %%
recent_grads['Women'].hist(bins=25, range=(0,3000))

# %% [markdown]
# **Creating a Scatter Matrix with Pandas**

# %%
import pandas.plotting as pplt

pplt.scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(6,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f42dbc02390>,
# ...
#       dtype=object)

# %%
pplt.scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f42dbab3d68>,
# ...
#       dtype=object)

# %% [markdown]
# **Creating Bar Plots**

# %%
##comparing percentage of women

ax1 = recent_grads[:10].plot.bar(x='Major', y='ShareWomen')
ax2 = recent_grads[-10:].plot.bar(x='Major', y='ShareWomen')

# %% [markdown]
# In this project we learned how to use the plotting tools available within the **pandas** library.
